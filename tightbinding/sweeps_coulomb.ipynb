# %% [markdown]
# # Altermagnetic superconductors

# %%
import kwant
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy.linalg as la
import scipy.sparse as sp
import scipy.sparse.linalg as sla
from amsc import (
    impurity_system,
    bulk_amsc_system,
    generate_intial_Delta,
    setup_gaussian_impurities,
    setup_spin_impurities,
    setup_Coulomb_impurities,
)
from plot_tools import add_tl_label, complex_plot
from scipy.interpolate import RegularGridInterpolator
from tqdm.notebook import tqdm
from pauli import *
from qm_tools import thermal_broadening, sparse_diag, sort_eigensystem

# %%
eigsh = sla.eigsh
# eigsh = sparse_diag # MUMPS

# %%
plt.style.use("../plot_style.mplstyle")

# %% [markdown]
# # System Setup

# %%
periodic_bc = True

Nx = 81
Ny = 81

x_ax = np.linspace(-(Nx // 2), (Nx // 2), Nx)
y_ax = np.linspace(-(Ny // 2), (Ny // 2), Ny)
x, y = np.meshgrid(x_ax, y_ax)

t = 5.0
t_so = 0.0 * t
t_am = 0.25 * t

mu = 2.0
hz0 = 1e-6
hx0 = 0
hy0 = 0

## Initial value for Delta (will be used to determine g)
Delta_init = 1

# %%
vortex_positions = []
windings = []
l_core = 0  # l_core is the decay length of the order parameter (in a vortex that is the coherence length)

Delta, theta = generate_intial_Delta(
    x=x,
    y=y,
    Delta_init=Delta_init,
    vortex_positions=vortex_positions,
    windings=windings,
    l_core=l_core,
)

# %%
# Impurituy positions
impurity_positions = [(0, 0)]  # , (-10, 0)]
impurity_sizes = [3]  # Sizes
impurity_eccentricities = [0.0]  # Eccentricity
impurity_orientation = [0.0]  # Orientation


V_imp = [-10]  # Impurity potential (negative = attractive)
hx_imp = [0.0]  # Impurity field
hy_imp = [0.0]  # Impurity field
hz_imp = [0.0]  # Impurity field

hx, hy, hz = setup_spin_impurities(
    x=x,
    y=y,
    hx0=hx0,
    hy0=hy0,
    hz0=hz0,
    impurity_sizes=impurity_sizes,
    impurity_positions=impurity_positions,
    impurity_eccentricities=impurity_eccentricities,
    impurity_orientations=impurity_orientation,
    hx_imp=hx_imp,
    hy_imp=hy_imp,
    hz_imp=hz_imp,
)

# %%
N = 80

# %% [markdown]
# ## V_0

# %%
Vss = np.linspace(-10, -90, 33)
wss = np.zeros((33, N))

vss = np.zeros((33, 4 * Nx**2, N), dtype=complex)

for i, Vs in tqdm(enumerate(Vss), total=len(Vss)):

    V = setup_Coulomb_impurities(
        x=x,
        y=y,
        mu=mu,
        impurity_positions=impurity_positions,
        V_imp=[Vs],
        screening_length=4,
    )

    syst, lat = bulk_amsc_system(
        Nx=Nx,
        Ny=Ny,
        t=t,
        t_so=t_so,
        t_am=t_am,
        V=V,
        Delta=Delta,
        theta=theta,
        hx=hx,
        hy=hy,
        hz=hz,
        periodic_bc=periodic_bc,
    )

    fsyst = syst.finalized()

    ws, vs = eigsh(fsyst.hamiltonian_submatrix(sparse=True), k=N, sigma=0)

    wss[i] = ws
    vss[i] = vs

wss, vss = sort_eigensystem(wss, vss)
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots()
ax.plot(-Vss, wss[:, :])
plt.xlabel(r"$-V_0$")
plt.ylabel(r"$\omega_n$")
fig.savefig("FigS3.svg")
fig.savefig("FigS3.pdf")

# %%
sizes = np.linspace(1, 6, 21)
wss = np.zeros((11, N))
vss = np.zeros((11, 4 * Nx**2, N), dtype=complex)

for i, size in tqdm(enumerate(sizes), total=len(sizes)):

    V, hx, hy, hz = setup_gaussian_impurities(
        x=x,
        y=y,
        mu=mu,
        hx0=hx0,
        hy0=hy0,
        hz0=hz0,
        impurity_sizes=[size],
        impurity_positions=impurity_positions,
        impurity_eccentricities=impurity_eccentricities,
        impurity_orientations=impurity_orientation,
        V_imp=[-10],
        hx_imp=hx_imp,
        hy_imp=hy_imp,
        hz_imp=hz_imp,
    )

    syst, lat = bulk_amsc_system(
        Nx=Nx,
        Ny=Ny,
        t=t,
        t_so=t_so,
        t_am=t_am,
        V=V,
        Delta=Delta,
        theta=theta,
        hx=hx,
        hy=hy,
        hz=hz,
        periodic_bc=periodic_bc,
    )

    fsyst = syst.finalized()

    ws, vs = eigsh(fsyst.hamiltonian_submatrix(sparse=True), k=N, sigma=0)

    wss[i] = ws
    vss[i] = vs

wss, vss = sort_eigensystem(wss, vss)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       3 vss = np.zeros((11, 4*Nx**2, N), dtype=complex)
#       5 for i, size in tqdm(enumerate(sizes), total=len(sizes)):
# ----> 7     V, hx, hy, hz = setup__impurities(
#       8         x=x,
#       9         y=y,
#      10         mu=mu,
#      11         hx0=hx0,
#      12         hy0=hy0,
#      13         hz0=hz0,
#      14         impurity_sizes=[size],
#      15         impurity_positions=impurity_positions,
#      16         impurity_eccentricities=impurity_eccentricities,
#      17         impurity_orientations=impurity_orientation,
#      18         V_imp=[-10],
#      19         hx_imp=hx_imp,
#      20         hy_imp=hy_imp,
#      21         hz_imp=hz_imp,
#      22     )
#      25     syst, lat = bulk_amsc_system(
#      26         Nx=Nx,
#      27         Ny=Ny,
#    (...)
#      37         periodic_bc=periodic_bc,
#      38         )
#      40     fsyst = syst.finalized()
#
# NameError: name 'setup__impurities' is not defined

# %%
plt.plot(sizes, wss);
# Out:
# [<matplotlib.lines.Line2D at 0x7f13c29d2d10>,
#  <matplotlib.lines.Line2D at 0x7f13c8c41dd0>,
#  <matplotlib.lines.Line2D at 0x7f13c9c5e3d0>,
#  <matplotlib.lines.Line2D at 0x7f13c29c6a50>,
#  <matplotlib.lines.Line2D at 0x7f13c29c4510>,
#  <matplotlib.lines.Line2D at 0x7f13c29c6150>,
#  <matplotlib.lines.Line2D at 0x7f13c29c6490>,
#  <matplotlib.lines.Line2D at 0x7f13c29e1890>,
#  <matplotlib.lines.Line2D at 0x7f13c85faa90>,
#  <matplotlib.lines.Line2D at 0x7f13c29c7e50>,
#  <matplotlib.lines.Line2D at 0x7f13c85fb8d0>,
#  <matplotlib.lines.Line2D at 0x7f13c29e30d0>,
#  <matplotlib.lines.Line2D at 0x7f13c8f50d90>,
#  <matplotlib.lines.Line2D at 0x7f13c29e14d0>,
#  <matplotlib.lines.Line2D at 0x7f13c29e29d0>,
#  <matplotlib.lines.Line2D at 0x7f13c29e0fd0>,
#  <matplotlib.lines.Line2D at 0x7f13c8986b10>,
#  <matplotlib.lines.Line2D at 0x7f13c883dd50>,
#  <matplotlib.lines.Line2D at 0x7f13c8635190>,
#  <matplotlib.lines.Line2D at 0x7f13c29e6010>,
#  <matplotlib.lines.Line2D at 0x7f13c29e7d10>,
#  <matplotlib.lines.Line2D at 0x7f13c29e4750>,
#  <matplotlib.lines.Line2D at 0x7f13c29e7390>,
#  <matplotlib.lines.Line2D at 0x7f13c8814c50>,
#  <matplotlib.lines.Line2D at 0x7f13c29ce910>,
#  <matplotlib.lines.Line2D at 0x7f13c29e6b50>,
#  <matplotlib.lines.Line2D at 0x7f13c29e7310>,
#  <matplotlib.lines.Line2D at 0x7f13c29d9190>,
#  <matplotlib.lines.Line2D at 0x7f13c29e0210>,
#  <matplotlib.lines.Line2D at 0x7f13c29da590>,
#  <matplotlib.lines.Line2D at 0x7f13c29d9050>,
#  <matplotlib.lines.Line2D at 0x7f13c29d8690>]

# %%
sizes = np.linspace(1, 6, 21)
wss = np.zeros((21, N))
vss = np.zeros((21, 4 * Nx**2, N), dtype=complex)


for i, size in tqdm(enumerate(sizes), total=len(sizes)):

    V, hx, hy, hz = setup_gaussian_impurities(
        x=x,
        y=y,
        mu=mu,
        hx0=hx0,
        hy0=hy0,
        hz0=hz0,
        impurity_sizes=[size],
        impurity_positions=impurity_positions,
        impurity_eccentricities=impurity_eccentricities,
        impurity_orientations=impurity_orientation,
        V_imp=[-16],
        hx_imp=hx_imp,
        hy_imp=hy_imp,
        hz_imp=hz_imp,
    )

    syst, lat = bulk_amsc_system(
        Nx=Nx,
        Ny=Ny,
        t=t,
        t_so=t_so,
        t_am=t_am,
        V=V,
        Delta=Delta,
        theta=theta,
        hx=hx,
        hy=hy,
        hz=hz,
        periodic_bc=periodic_bc,
    )

    fsyst = syst.finalized()

    ws, vs = eigsh(fsyst.hamiltonian_submatrix(sparse=True), k=N, sigma=0)

    wss[i] = ws
    vss[i] = vs
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
wss, vss = sort_eigensystem(wss, vss)
plt.plot(sizes, wss)
plt.xlabel(r"$S$")
# Out:
# Text(0.5, 0, '$S$')

# %%
Vss = np.linspace(-10, -30, 11)
wss = np.zeros((11, N))
vss = np.zeros((11, 4 * Nx**2, N), dtype=complex)

for i, Vs in tqdm(enumerate(Vss), total=len(Vss)):

    V, hx, hy, hz = setup_gaussian_impurities(
        x=x,
        y=y,
        mu=mu,
        hx0=hx0,
        hy0=hy0,
        hz0=hz0,
        impurity_sizes=[2],
        impurity_positions=impurity_positions,
        impurity_eccentricities=impurity_eccentricities,
        impurity_orientations=impurity_orientation,
        V_imp=[Vs],
        hx_imp=hx_imp,
        hy_imp=hy_imp,
        hz_imp=hz_imp,
    )

    syst, lat = bulk_amsc_system(
        Nx=Nx,
        Ny=Ny,
        t=t,
        t_so=t_so,
        t_am=t_am,
        V=V,
        Delta=Delta,
        theta=theta,
        hx=hx,
        hy=hy,
        hz=hz,
        periodic_bc=periodic_bc,
    )

    fsyst = syst.finalized()

    ws, vs = eigsh(fsyst.hamiltonian_submatrix(sparse=True), k=N, sigma=0)

    wss[i] = ws
    vss[i] = vs
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
wss, vss = sort_eigensystem(wss, vss)

plt.plot(-Vss, wss)
plt.xlabel(r"$-V_0$")
plt.ylabel(r"$\omega_s$")
# Out:
# Text(0, 0.5, '$\\omega_s$')
